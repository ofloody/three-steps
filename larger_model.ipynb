# %%
# Set your API key
from nnsight import CONFIG
from nnsight.modeling.language import LanguageModel
from dotenv import load_dotenv
import os
CONFIG.set_default_api_key(os.environ["NDIF_API_KEY"])
CONFIG.API.HOST = "https://api.ndif.us"
CONFIG.save()
# Load model: We'll never actually load the parameters so no need to specify a device_map.
model = LanguageModel("openai-community/gpt2")
llm = LanguageModel("EleutherAI/gpt-j-6b", device_map="auto")

# To specify using NDIF remotely instead of executing locally, set remote=True.
with model.trace("The Eiffel Tower is in the city of", remote=True):
    hidden_state = model.transformer.h[3].output.save()
    output = model.output.save()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File /opt/miniconda3/envs/new-env/lib/python3.12/site-packages/huggingface_hub/utils/_http.py:402, in hf_raise_for_status(response, endpoint_name)
#     401 try:
# --> 402     response.raise_for_status()
#     403 except HTTPError as e:
#
# File /opt/miniconda3/envs/new-env/lib/python3.12/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 403 Client Error: Forbidden for url: https://huggingface.co/meta-llama/Llama-3.1-70B/resolve/main/config.json
#
# The above exception was the direct cause of the following exception:
#
# HfHubHTTPError                            Traceback (most recent call last)
# File /opt/miniconda3/envs/new-env/lib/python3.12/site-packages/huggingface_hub/file_download.py:1543, in _get_metadata_or_catch_error(repo_id, filename, repo_type, revision, endpoint, proxies, etag_timeout, headers, token, local_files_only, relative_filename, storage_folder)
#    1542 try:
# -> 1543     metadata = get_hf_file_metadata(
#    1544         url=url, proxies=proxies, timeout=etag_timeout, headers=headers, token=token, endpoint=endpoint
#    1545     )
#    1546 except EntryNotFoundError as http_error:
#
# File /opt/miniconda3/envs/new-env/lib/python3.12/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File /opt/miniconda3/envs/new-env/lib/python3.12/site-packages/huggingface_hub/file_download.py:1460, in get_hf_file_metadata(url, token, proxies, timeout, library_name, library_version, user_agent, headers, endpoint)
#    1459 # Retrieve metadata
# -> 1460 r = _request_wrapper(
#    1461     method="HEAD",
#    1462     url=url,
#    1463     headers=hf_headers,
#    1464     allow_redirects=False,
#    1465     follow_relative_redirects=True,
#    1466     proxies=proxies,
#    1467     timeout=timeout,
#    1468 )
#    1469 hf_raise_for_status(r)
#
# File /opt/miniconda3/envs/new-env/lib/python3.12/site-packages/huggingface_hub/file_download.py:283, in _request_wrapper(method, url, follow_relative_redirects, **params)
#     282 if follow_relative_redirects:
# --> 283     response = _request_wrapper(
#     284         method=method,
#     285         url=url,
#     286         follow_relative_redirects=False,
#     287         **params,
#     288     )
#     290     # If redirection, we redirect only relative paths.
#     291     # This is useful in case of a renamed repository.
#
# File /opt/miniconda3/envs/new-env/lib/python3.12/site-packages/huggingface_hub/file_download.py:307, in _request_wrapper(method, url, follow_relative_redirects, **params)
#     306 response = http_backoff(method=method, url=url, **params)
# --> 307 hf_raise_for_status(response)
#     308 return response
#
# File /opt/miniconda3/envs/new-env/lib/python3.12/site-packages/huggingface_hub/utils/_http.py:466, in hf_raise_for_status(response, endpoint_name)
#     461     message = (
#     462         f"\n\n{response.status_code} Forbidden: {error_message}."
#     463         + f"\nCannot access content at: {response.url}."
#     464         + "\nMake sure your token has the correct permissions."
#     465     )
# --> 466     raise _format(HfHubHTTPError, message, response) from e
#     468 elif response.status_code == 416:
#
# HfHubHTTPError: (Request ID: Root=1-69418850-67e494c8601216d46ba7d26f;53a5f919-1420-4841-8650-3cf16e468cdb)
#
# 403 Forbidden: Please enable access to public gated repositories in your fine-grained token settings to view this repository..
# Cannot access content at: https://huggingface.co/meta-llama/Llama-3.1-70B/resolve/main/config.json.
# Make sure your token has the correct permissions.
#
# The above exception was the direct cause of the following exception:
#
# LocalEntryNotFoundError                   Traceback (most recent call last)
# File /opt/miniconda3/envs/new-env/lib/python3.12/site-packages/transformers/utils/hub.py:479, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     477 if len(full_filenames) == 1:
#     478     # This is slightly better for only 1 file
# --> 479     hf_hub_download(
#     480         path_or_repo_id,
#     481         filenames[0],
#     482         subfolder=None if len(subfolder) == 0 else subfolder,
#     483         repo_type=repo_type,
#     484         revision=revision,
#     485         cache_dir=cache_dir,
#     486         user_agent=user_agent,
#     487         force_download=force_download,
#     488         proxies=proxies,
#     489         resume_download=resume_download,
#     490         token=token,
#     491         local_files_only=local_files_only,
#     492     )
#     493 else:
#
# File /opt/miniconda3/envs/new-env/lib/python3.12/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File /opt/miniconda3/envs/new-env/lib/python3.12/site-packages/huggingface_hub/file_download.py:1007, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, proxies, etag_timeout, token, local_files_only, headers, endpoint, resume_download, force_filename, local_dir_use_symlinks)
#    1006 else:
# -> 1007     return _hf_hub_download_to_cache_dir(
#    1008         # Destination
#    1009         cache_dir=cache_dir,
#    1010         # File info
#    1011         repo_id=repo_id,
#    1012         filename=filename,
#    1013         repo_type=repo_type,
#    1014         revision=revision,
#    1015         # HTTP info
#    1016         endpoint=endpoint,
#    1017         etag_timeout=etag_timeout,
#    1018         headers=hf_headers,
#    1019         proxies=proxies,
#    1020         token=token,
#    1021         # Additional options
#    1022         local_files_only=local_files_only,
#    1023         force_download=force_download,
#    1024     )
#
# File /opt/miniconda3/envs/new-env/lib/python3.12/site-packages/huggingface_hub/file_download.py:1114, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, proxies, token, local_files_only, force_download)
#    1113     # Otherwise, raise appropriate error
# -> 1114     _raise_on_head_call_error(head_call_error, force_download, local_files_only)
#    1116 # From now on, etag, commit_hash, url and size are not None.
#
# File /opt/miniconda3/envs/new-env/lib/python3.12/site-packages/huggingface_hub/file_download.py:1658, in _raise_on_head_call_error(head_call_error, force_download, local_files_only)
#    1656 else:
#    1657     # Otherwise: most likely a connection issue or Hub downtime => let's warn the user
# -> 1658     raise LocalEntryNotFoundError(
#    1659         "An error happened while trying to locate the file on the Hub and we cannot find the requested files"
#    1660         " in the local cache. Please check your connection and try again or make sure your Internet connection"
#    1661         " is on."
#    1662     ) from head_call_error
#
# LocalEntryNotFoundError: An error happened while trying to locate the file on the Hub and we cannot find the requested files in the local cache. Please check your connection and try again or make sure your Internet connection is on.
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[3], line 9
#       7 # Load model: We'll never actually load the parameters so no need to specify a device_map.
#       8 model = LanguageModel("openai-community/gpt2")
# ----> 9 llm = LanguageModel("meta-llama/Llama-3.1-70B", device_map="auto")
#      11 # To specify using NDIF remotely instead of executing locally, set remote=True.
#      12 with model.trace("The Eiffel Tower is in the city of", remote=True):
#
# File /opt/miniconda3/envs/new-env/lib/python3.12/site-packages/nnsight/modeling/language.py:74, in LanguageModel.__init__(self, tokenizer, automodel, *args, **kwargs)
#      64 def __init__(
#      65     self,
#      66     *args,
#    (...)     69     **kwargs,
#      70 ) -> None:
#      72     self.tokenizer: PreTrainedTokenizer = tokenizer
# ---> 74     super().__init__(*args, automodel=automodel, **kwargs)
#      76     self.generator: Envoy = LanguageModel.Generator()
#
# File /opt/miniconda3/envs/new-env/lib/python3.12/site-packages/nnsight/modeling/transformers.py:23, in TransformersModel.__init__(self, config_model, automodel, *args, **kwargs)
#      15 self.config: PretrainedConfig = config_model
#      17 self.automodel = (
#      18     automodel
#      19     if not isinstance(automodel, str)
#      20     else getattr(modeling_auto, automodel)
#      21 )
# ---> 23 super().__init__(*args, **kwargs)
#
# File /opt/miniconda3/envs/new-env/lib/python3.12/site-packages/nnsight/modeling/huggingface.py:29, in HuggingFaceModel.__init__(self, repo_id, revision, import_edits, *args, **kwargs)
#      22 self.repo_id = (
#      23     repo_id
#      24     if isinstance(repo_id, str)
#      25     else getattr(repo_id, "name_or_path", None)
#      26 )
#      27 self.revision = revision
# ---> 29 super().__init__(repo_id, *args, revision=revision, **kwargs)
#      31 if import_edits:
#      33     if isinstance(import_edits, str):
#
# File /opt/miniconda3/envs/new-env/lib/python3.12/site-packages/nnsight/modeling/mixins/meta.py:40, in MetaMixin.__init__(self, dispatch, meta_buffers, rename, *args, **kwargs)
#      36 else:
#      38     with init_empty_weights(include_buffers=meta_buffers):
# ---> 40         model = self._load_meta(*args, **kwargs)
#      42     NNsight.__init__(self, model, rename=rename)
#      44 self.args = args
#
# File /opt/miniconda3/envs/new-env/lib/python3.12/site-packages/nnsight/modeling/language.py:86, in LanguageModel._load_meta(self, repo_id, revision, tokenizer_kwargs, **kwargs)
#      78 def _load_meta(
#      79     self,
#      80     repo_id: str,
#    (...)     83     **kwargs,
#      84 ):
# ---> 86     self._load_config(repo_id, revision=revision, **kwargs)
#      88     self._load_tokenizer(repo_id, revision=revision, **tokenizer_kwargs)
#      90     model = super()._load_meta(repo_id, revision=revision, **kwargs)
#
# File /opt/miniconda3/envs/new-env/lib/python3.12/site-packages/nnsight/modeling/transformers.py:29, in TransformersModel._load_config(self, repo_id, revision, **kwargs)
#      25 def _load_config(self, repo_id: str, revision: Optional[str] = None, **kwargs):
#      27     if self.config is None:
# ---> 29         self.config = AutoConfig.from_pretrained(
#      30             repo_id, revision=revision, **kwargs
#      31         )
#
# File /opt/miniconda3/envs/new-env/lib/python3.12/site-packages/transformers/models/auto/configuration_auto.py:1332, in AutoConfig.from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#    1329 trust_remote_code = kwargs.pop("trust_remote_code", None)
#    1330 code_revision = kwargs.pop("code_revision", None)
# -> 1332 config_dict, unused_kwargs = PretrainedConfig.get_config_dict(pretrained_model_name_or_path, **kwargs)
#    1333 has_remote_code = "auto_map" in config_dict and "AutoConfig" in config_dict["auto_map"]
#    1334 has_local_code = "model_type" in config_dict and config_dict["model_type"] in CONFIG_MAPPING
#
# File /opt/miniconda3/envs/new-env/lib/python3.12/site-packages/transformers/configuration_utils.py:662, in PretrainedConfig.get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     660 original_kwargs = copy.deepcopy(kwargs)
#     661 # Get config dict associated with the base config file
# --> 662 config_dict, kwargs = cls._get_config_dict(pretrained_model_name_or_path, **kwargs)
#     663 if config_dict is None:
#     664     return {}, kwargs
#
# File /opt/miniconda3/envs/new-env/lib/python3.12/site-packages/transformers/configuration_utils.py:721, in PretrainedConfig._get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     717 configuration_file = kwargs.pop("_configuration_file", CONFIG_NAME) if gguf_file is None else gguf_file
#     719 try:
#     720     # Load from local folder or from cache or download from model Hub and cache
# --> 721     resolved_config_file = cached_file(
#     722         pretrained_model_name_or_path,
#     723         configuration_file,
#     724         cache_dir=cache_dir,
#     725         force_download=force_download,
#     726         proxies=proxies,
#     727         resume_download=resume_download,
#     728         local_files_only=local_files_only,
#     729         token=token,
#     730         user_agent=user_agent,
#     731         revision=revision,
#     732         subfolder=subfolder,
#     733         _commit_hash=commit_hash,
#     734     )
#     735     if resolved_config_file is None:
#     736         return None, kwargs
#
# File /opt/miniconda3/envs/new-env/lib/python3.12/site-packages/transformers/utils/hub.py:322, in cached_file(path_or_repo_id, filename, **kwargs)
#     264 def cached_file(
#     265     path_or_repo_id: Union[str, os.PathLike],
#     266     filename: str,
#     267     **kwargs,
#     268 ) -> Optional[str]:
#     269     """
#     270     Tries to locate a file in a local folder and repo, downloads and cache it if necessary.
#     271
#    (...)    320     ```
#     321     """
# --> 322     file = cached_files(path_or_repo_id=path_or_repo_id, filenames=[filename], **kwargs)
#     323     file = file[0] if file is not None else file
#     324     return file
#
# File /opt/miniconda3/envs/new-env/lib/python3.12/site-packages/transformers/utils/hub.py:553, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     550     # Here we only raise if both flags for missing entry and connection errors are True (because it can be raised
#     551     # even when `local_files_only` is True, in which case raising for connections errors only would not make sense)
#     552     elif _raise_exceptions_for_missing_entries:
# --> 553         raise OSError(
#     554             f"We couldn't connect to '{HUGGINGFACE_CO_RESOLVE_ENDPOINT}' to load the files, and couldn't find them in the"
#     555             f" cached files.\nCheck your internet connection or see how to run the library in offline mode at"
#     556             " 'https://huggingface.co/docs/transformers/installation#offline-mode'."
#     557         ) from e
#     558 # snapshot_download will not raise EntryNotFoundError, but hf_hub_download can. If this is the case, it will be treated
#     559 # later on anyway and re-raised if needed
#     560 elif isinstance(e, HTTPError) and not isinstance(e, EntryNotFoundError):
#
# OSError: We couldn't connect to 'https://huggingface.co' to load the files, and couldn't find them in the cached files.
# Check your internet connection or see how to run the library in offline mode at 'https://huggingface.co/docs/transformers/installation#offline-mode'.
